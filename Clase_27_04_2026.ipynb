# %%
import pymcel as pc
import numpy as np
import matplotlib.pyplot as plt

# %%
e = 0.1911663355386932		
a= 0.9223803173917017	
q = 0.7460522521429133	
i = 3.340958441017069	
node = 203.8996515621043	
peri = 126.6728325163065	
M = 312.8054663584516	
tp = 2461042.918242006079 #dias
