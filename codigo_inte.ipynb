# %%
import pymcel as pc
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##Trayectoria del vector relativo en el sitena perifocal

# %%
p = 1.0
e = 0.7
theta = np.linspace(0, 2*np.pi, 100)
rs= p / (1 + e* np.cos(theta))

xfs = rs * np.cos(theta)
yfs = rs * np.sin(theta)
# pondremos el origen en el foco

plt.plot(xfs, yfs)
plt.plot(0, 0, 'yo', label='Sun')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Orbit of a planet around the sun')
plt.grid()
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
def dibuja_orbita(e):
    p=1.0
    theta = np.linspace(0, 2*np.pi, 100)
    rs= p / (1 + e* np.cos(theta))

    xfs = rs * np.cos(theta)
    yfs = rs * np.sin(theta)

    plt.plot(xfs, yfs)
    plt.plot(0, 0, 'yo', label='Sun')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Orbit of a planet around the sun')
    plt.grid()
    plt.axis('equal')
    plt.tight_layout()
    plt.show()

# %%
# %pip install --upgrade ipywidgets
# Out:
# Collecting ipywidgets
#   Using cached ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: comm>=0.1.3 in .\mec-nica-celeste\Lib\site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in .\mec-nica-celeste\Lib\site-packages (from ipywidgets) (9.10.0)
# Requirement already satisfied: traitlets>=4.3.1 in .\mec-nica-celeste\Lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in .\mec-nica-celeste\Lib\site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in .\mec-nica-celeste\Lib\site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: colorama>=0.4.4 in .\mec-nica-celeste\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in .\mec-nica-celeste\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in .\mec-nica-celeste\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in .\mec-nica-celeste\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in .\mec-nica-celeste\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in .\mec-nica-celeste\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in .\mec-nica-celeste\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in .\mec-nica-celeste\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in .\mec-nica-celeste\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (4.15.0)
# Requirement already satisfied: wcwidth in .\mec-nica-celeste\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in .\mec-nica-celeste\Lib\site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets) (0.8.6)
# Requirement already satisfied: executing>=1.2.0 in .\mec-nica-celeste\Lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in .\mec-nica-celeste\Lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure-eval in .\mec-nica-celeste\Lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)
# Using cached ipywidgets-8.1.8-py3-none-any.whl (139 kB)
# Installing collected packages: ipywidgets
# Successfully installed ipywidgets-8.1.8
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~andas (c:\Users\nando\Repositorio-git-Mcenica-celeste\mec-nica-celeste\mec-nica-celeste\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (c:\Users\nando\Repositorio-git-Mcenica-celeste\mec-nica-celeste\mec-nica-celeste\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (c:\Users\nando\Repositorio-git-Mcenica-celeste\mec-nica-celeste\mec-nica-celeste\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (c:\Users\nando\Repositorio-git-Mcenica-celeste\mec-nica-celeste\mec-nica-celeste\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (c:\Users\nando\Repositorio-git-Mcenica-celeste\mec-nica-celeste\mec-nica-celeste\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (c:\Users\nando\Repositorio-git-Mcenica-celeste\mec-nica-celeste\mec-nica-celeste\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (c:\Users\nando\Repositorio-git-Mcenica-celeste\mec-nica-celeste\mec-nica-celeste\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (c:\Users\nando\Repositorio-git-Mcenica-celeste\mec-nica-celeste\mec-nica-celeste\Lib\site-packages)

# %%
import ipywidgets as widgets
from ipywidgets import interact

def dibuja_orbita(e):
    p = 1.0
    theta = np.linspace(0, 2*np.pi, 100)
    rs = p / (1 + e * np.cos(theta))

    xfs = rs * np.cos(theta)
    yfs = rs * np.sin(theta)

    plt.plot(xfs, yfs)
    plt.plot(0, 0, 'yo', label='Sun')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Orbit of a planet around the sun')
    plt.grid()
    plt.axis('equal')
    plt.tight_layout()
    plt.show()
# Out:
# interactive(children=(FloatSlider(value=0.0, description='e', max=0.9, min=-0.9), Output()), _dom_classes=('wi…

# %%
interact(dibuja_orbita, e=(-0.9, 0.9, 0.1))
# Out:
#   Cell In[6], line 2
#     dibuja_orbita(0.7)
#     ^
# SyntaxError: invalid syntax
